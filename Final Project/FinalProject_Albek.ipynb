# %%
print("                        PYTHON BİLGİ YARIŞMASINA HOŞGELDİNİZ                  ")

soru1 =  input("Soru - 1\n Python'da string ifadeleri tamamını büyük olarak yazdıran metod hangisidir?\n A) strip()\n B) upper()\n C)split()\n D)append()\n Lütfen cevabı giriniz:")

soru2 =  input("Soru - 2\n Python'da 'Hello World' çıktısını hangisi verir?\n A) p('Hello World')\n B) echo('Hello world');\n C) p('Hello world')\n D) print('Hello World')\n Lütfen cevabı giriniz:")

soru3 =  input("Soru - 3\n Python'da hangisi dosya uzantısıdır?\n A) .pyth\n B) .pt\n C) .py\n D) .ph\n Lütfen cevabı giriniz:")

soru4 =  input("Soru - 4\n Aşağıdakilerden hangisi değişken ismi olarak kullanılabilir?\n A) 1sayi\n B) birinci.sayı\n C) sayi1\n D) 2incisayı\n Lütfen cevabı giriniz:")

soru5 =  input("Soru - 5\n len('Programlama')\n Aşağıdakilerden hangisi yukarıda verilen Python komut satırı çalıştırıldığında programın vereceği çıktıdır ?\n A) prg\n B) 11\n C) len\n D) Programlama\n Lütfen cevabı giriniz:")

soru6 =  input("Soru - 6\n liste.append() komutunun görevi aşağıdakilerden hangisidir ?\n A) Listede kaç elaman olduğunu, karakter sayısını verir.\n B) Liste oluşturmayı sağlar.\n C) Listeden eleman silmeyi sağlar.\n D) Listeye yeni eleman eklemeyi sağlar.\n Lütfen cevabı giriniz:")

soru7 =  input("Soru - 7\n Aşağıdaki karşılaştırma operatörlerinden hangisi eşitse ifadesinin karşılığıdır ?\n A) =!\n B) ==\n C) =<\n D) <>\n Lütfen cevabı giriniz:")

soru8 =  input("Soru - 8\n Aşağıdaki operatörlerinden hangisi üs alma (Örn: 4' ün küpü) ifadesinin karşılığıdır ?\n A) ==\n B) =!\n C) **\n D) *\n Lütfen cevabı giriniz:")

soru9 =  input("Soru - 9\n Metinsel bir ifadeyi Sayısal bir ifadeye çevirmek için hangi komutu kullanırız ?\n A) numeric()\n B) str()\n C) float()\n D) int()\n Lütfen cevabı giriniz:")

soru10 =  input("Soru - 10\n Hangisi bir stringin başındaki boşluğu kaldırır ?\n A) trim()\n B) ptrim()\n C) strip()\n D) len()\n Lütfen cevabı giriniz:")
 

toplam = 0
if soru1 == "b" or soru1 == "B":
  toplam += 10
if soru2 == "D" or soru2 == "d":
  toplam += 10
if soru3 == "C" or soru3 =="c":
  toplam += 10
if soru4 == "C" or soru4 =="c":
  toplam += 10
if soru5 == "B" or soru5 =="b":
  toplam += 10
if soru6 == "D" or soru6 =="d":
  toplam += 10
if soru7 == "B" or soru7 =="b":
  toplam += 10
if soru8 == "C" or soru8 =="c":
  toplam += 10
if soru9 == "D" or soru9 =="d":
  toplam += 10
if soru10 == "C" or soru10 =="c":
  toplam += 10



if toplam <= 50:
  again = input(f"{toplam} ile arışmamızı geçemediniz haftaya olan yarışmaya katılmak ister misiniz ?\n (E/H):" )
  if again == "e" or again == "E":
    print("Başvuru kaydınız alınmıştır.Teşekkür ederiz...")
  else:
    print("Yarışmamıza katıldığınız için teşekkür ederi<...")

else: 
  print(f"{toplam} puan ile yarışmamızda başarılı oldunuz,TEBRİKLER...")
# Out:
#                         PYTHON BİLGİ YARIŞMASINA HOŞGELDİNİZ
# Soru - 1
#  Python'da string ifadeleri tamamını büyük olarak yazdıran metod hangisidir?
#  A) strip()
#  B) upper()
#  C)split()
#  D)append()
#  Lütfen cevabı giriniz:b
# Soru - 2
#  Python'da 'Hello World' çıktısını hangisi verir?
#  A) p('Hello World')
#  B) echo('Hello world');
#  C) p('Hello world')
#  D) print('Hello World')
#  Lütfen cevabı giriniz:d
# Soru - 3
#  Python'da hangisi dosya uzantısıdır?
#  A) .pyth
#  B) .pt
#  C) .py
#  D) .ph
#  Lütfen cevabı giriniz:c
# Soru - 4
#  Aşağıdakilerden hangisi değişken ismi olarak kullanılabilir?
#  A) 1sayi
#  B) birinci.sayı
#  C) sayi1
#  D) 2incisayı
#  Lütfen cevabı giriniz:c
# Soru - 5
#  len('Programlama')
#  Aşağıdakilerden hangisi yukarıda verilen Python komut satırı çalıştırıldığında programın vereceği çıktıdır ?
#  A) prg
#  B) 11
#  C) len
#  D) Programlama
#  Lütfen cevabı giriniz:b
# Soru - 6
#  liste.append() komutunun görevi aşağıdakilerden hangisidir ?
# ...
